# %% [markdown]
# /////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# #### https://education.github.com/git-cheat-sheet-education.pdf
# /////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////

# %% [markdown]
# ## INITIALIZING
# /////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
#
# ### Download and install git...
#
# /////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
#
# ## STARTING IT UP
# /////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
#
# ### Updating global settings...
#
#  git config --global user.name "YourUserName"
#
#  git config --global user.email yourEmailID_G_Hub
#
#  git config --global init.default branch main
#
#  #### POSIIBLE ERROR FIXES:
#  For those who are using access token and a Windows environment, there is a simple way to do it:
#  Start menu → Credential Manager → Windows Credentials → find the line (Git: https://whatever/your-repository/url) → edit, user name is "github_username" and password is your access token.
#  Access Token create a PAT with temporary permissions...
#
#  git config --global --unset credential.helper
#
#  Delete at the end of the day...
#
#  ### cd into the required location...
#
#  git init
#
#  #### To initialize a new repository at the required location...
#
#  git status
#
#  #### Displays the current status of the file...
#
#  git add .
#
#  #### Adds all files in the working directory to the staging area...
#
#  git add filename
#
#  #### Adds only one specific file to the staging area...
#
#  git rm --cached filename
#
#  #### Removes a file from the staging area but keeps it in the working directory...
#
#  ### .gitignore
#  #### If you want to ignore certain files or directories...
#
#  #### ' # ' acts as a comment...
#  #### example:
#  #### *.txt
#  #### filename.extension
#  #### ignores all text files in your local repo...

# %% [markdown]
# ### Committing changes to the repository...
#  #### start with :
#
#  git status
#
#  #### to check which are all the staged changes...
#
#  git add .
#
#  git commit -m "Some message"
#
#  ### Post commit...
#  #### You can view history using...
#  git log
#
#  #### any more changes done... the diffrences can be viewed with
#  git diff
#
#  ### To remove any staged changes without deleting the file we use:
#  git restore --staged filename
#
#  ### option exists to bypass staging...
#  git commit -a -m "message..."
#
#  ### to remove a file...
#  git rm "filename"
#
#  ### to restore it...
#  git restore "filename"
#  #### Provided you have a previous commited version
#
#  git mv "oldfilename" "newfilenamw"
#  #### rename a file thrugh bash...
#
#  git commit -m "new commit message..." --amend
#  #### change last commits message...without having to commit again!
#
#  git reset commit#
#  #### This will undo everything after that commit.
#  ![image.png](attachment:image.png)

# %% [markdown]
# #### Some extra tips
# git rebase -i --root
#
#  #### pulls up all the commit changes history...
#
# ### Branching
#  git branch newname
#
#  #### to view branch
#  git branch
#
#  #### switching to a new branch...
#  git switch branchname
